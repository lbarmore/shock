# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

#if the letter after a slash is lowercase, use two slashes
"""
file1 = "Z:\\\\TPX\\18-620\Analysis\PDVCh1.dat"
file2 = "Z:\\\\TPX\\18-620\Analysis\PDVCh2.dat"
file3 = "Z:\\\\TPX\\18-620\Analysis\PDVCh3.dat"
file4 = "Z:\\\\TPX\\18-620\Analysis\PDVCh4.dat"
file5 = "Z:\\\\TPX\\18-620\Analysis\VISARvelocity0.dat"
file6 = "Z:\\\\TPX\\18-620\Analysis\VISARvelocity1.dat"
file7 = "Z:\\\\TPX\\18-620\Analysis\VISARvelocity2.dat"
file8 = "Z:\\\\TPX\\18-620\Analysis\VISARvelocity3.dat"

f18v1 = "Z:\\\\TPX\\18-018\Analysis\\velocity0centerprobe-correct.dat"
f18v2 = "Z:\\\\TPX\\18-018\Analysis\\velocity1edgeprobe-correct.dat"
f18p1 = "Z:\\\\TPX\\18-018\Analysis\PDV1velocity_corrected.dat"
f18p2 = "Z:\\\\TPX\\18-018\Analysis\PDV2velocity_corrected.dat"
f18p3 = "Z:\\\\TPX\\18-018\Analysis\PDV3velocity_corrected.dat"
f18p4 = "Z:\\\\TPX\\18-018\Analysis\PDV4velocity.dat"

f23v0 = "Z:\\\\TPX\\18-023\Analysis\VISAR\\velocity0.dat"
f23v1 = "Z:\\\\TPX\\18-023\Analysis\VISAR\\velocity1.dat"
f23v2 = "Z:\\\\TPX\\18-023\Analysis\VISAR\\velocity2.dat"
f23v3 = "Z:\\\\TPX\\18-023\Analysis\VISAR\\velocity3.dat"
f23p1 = "Z:\\\\TPX\\18-023\Analysis\PDV\\velocityCh1.dat"
f23p2 = "Z:\\\\TPX\\18-023\Analysis\PDV\\velocityCh2.dat"
f23p3 = "Z:\\\\TPX\\18-023\Analysis\PDV\\velocityCh3.dat"
f23p4 = "Z:\\\\TPX\\18-023\Analysis\PDV\\velocityCh4.dat"

t1 = []
v1 = []
t2 = []
v2 = []
t3 = []
v3 = []
t4 = []
v4 = []
t5 = []
v5 = []
t6 = []
v6 = []
t7 = []
v7 = []
t8 = []
v8 = []

ta = []
va = []
tb = []
vb = []
tc = []
vc = []
td = []
vd = []
te = []
ve = []
tf = []
vf = []

t11 = []
v11 = []
t21 = []
v21 = []
t31 = []
v31 = []
t41 = []
v41 = []
t51 = []
v51 = []
t61 = []
v61 = []
t71 = []
v71 = []
t81 = []
v81 = []

f2s1 = "Z:\\\\TPX\\18-2s16\Analysis\VISARvelocity0.dat"
f2s2 = "Z:\\\\TPX\\18-2s16\Analysis\VISARvelocity1.dat"
f2s3 = "Z:\\\\TPX\\18-2s16\Analysis\VISARvelocity2.dat"
f2s4 = "Z:\\\\TPX\\18-2s16\Analysis\VISARvelocity3.dat"
f2s5 = "Z:\\\\TPX\\18-2s16\Analysis\PDVvelocity1.dat"
f2s6 = "Z:\\\\TPX\\18-2s16\Analysis\PDVvelocity2.dat"
f2s7 = "Z:\\\\TPX\\18-2s16\Analysis\PDVvelocity3.dat"
f2s8 = "Z:\\\\TPX\\18-2s16\Analysis\PDVvelocity4.dat"
"""

f2s1 = "Z:\\\\TPX\\18-2s19\Analysis\VISARvelocity0.dat"
f2s2 = "Z:\\\\TPX\\18-2s19\Analysis\VISARvelocity1.dat"
f2s3 = "Z:\\\\TPX\\18-2s19\Analysis\VISARvelocity2.dat"
f2s4 = "Z:\\\\TPX\\18-2s19\Analysis\VISARvelocity3.dat"
f2s5 = "Z:\\\\TPX\\18-2s19\Analysis\PDVvelocity1.dat"
f2s6 = "Z:\\\\TPX\\18-2s19\Analysis\PDVvelocity2.dat"
f2s7 = "Z:\\\\TPX\\18-2s19\Analysis\PDVvelocity3.dat"
f2s8 = "Z:\\\\TPX\\18-2s19\Analysis\PDVvelocity4.dat"

t1 = []
v1 = []
t2 = []
v2 = []
t3 = []
v3 = []
t4 = []
v4 = []
t5 = []
v5 = []
t6 = []
v6 = []
t7 = []
v7 = []
t8 = []
v8 = []

# %%
t1,v1 = np.loadtxt(f2s1, delimiter=',', unpack=True)
t2,v2 = np.loadtxt(f2s2, delimiter=',', unpack=True)
t3,v3 = np.loadtxt(f2s3, delimiter=',', unpack=True)
t4,v4 = np.loadtxt(f2s4, delimiter=',', unpack=True)
t5,v5 = np.loadtxt(f2s5, delimiter=',', unpack=True)
t6,v6 = np.loadtxt(f2s6, delimiter=',', unpack=True)
t7,v7 = np.loadtxt(f2s7, delimiter=',', unpack=True)
t8,v8 = np.loadtxt(f2s8, delimiter=',', unpack=True)

"""
ta,va = np.loadtxt(f18v1, delimiter=',', unpack=True)
tb,vb = np.loadtxt(f18v2, delimiter=',', unpack=True)
tc,vc = np.loadtxt(f18p1, delimiter=',', unpack=True)
td,vd = np.loadtxt(f18p2, delimiter=',', unpack=True)
te,ve = np.loadtxt(f18p3, delimiter=',', unpack=True)
tf,vf = np.loadtxt(f18p4, delimiter=',', unpack=True)
t11,v11 = np.loadtxt(f23v0, delimiter=',', unpack=True)
t21,v21 = np.loadtxt(f23v1, delimiter=',', unpack=True)
t31,v31 = np.loadtxt(f23v2, delimiter=',', unpack=True)
t41,v41 = np.loadtxt(f23v3, delimiter=',', unpack=True)
t51,v51 = np.loadtxt(f23p1, delimiter=',', unpack=True)
t61,v61 = np.loadtxt(f23p2, delimiter=',', unpack=True)
t71,v71 = np.loadtxt(f23p3, delimiter=',', unpack=True)
t81,v81 = np.loadtxt(f23p4, delimiter=',', unpack=True)
"""

#shift VISAR data forward to line up with PDV (didn't correlate VISAR timings)
t1 = [x+.18 for x in t1]
t2 = [x+.18 for x in t2]
t3 = [x+.172 for x in t3]
t4 = [x+.18 for x in t4]

#adjust PDV shot vertically for downshift
v5 = [5.42101-x for x in v5]
v6 = [5.42240-x for x in v6]
v7 = [5.42235-x for x in v7]
v8 = [5.42082-x for x in v8]

#clean up after wave leaves sample
t1 = [i for i in t1 if i <= 10.17]
v1 = v1[:len(t1)]
t2 = [i for i in t2 if i <= 9.785]
v2 = v2[:len(t2)]
t3 = [i for i in t3 if i <= 10.17]
v3 = v3[:len(t3)]

t5 = [i for i in t5 if i <= 10.1553]
v5 = v5[:len(t5)]
t6 = [i for i in t6 if i <= 9.8]
v6 = v6[:len(t6)]
t7 = [i for i in t7 if i <= 9.8]
v7 = v7[:len(t7)]
t8 = [i for i in t6 if i <= 9.8]
v8 = v8[:len(t8)]



"""
t21 = [x+.1 for x in t21]
t41 = [x+.1 for x in t41]
tb = [x+.1 for x in tb]
tc = [x-.1 for x in tc]
td = [x-.1 for x in td]
te = [x-.1 for x in te]
tf = [x-.1 for x in tf]


#scale PG shot vertically
v1 = [x*.357 for x in v1]
v2 = [x*.357 for x in v2]
v3 = [x*.357 for x in v3]
v4 = [x*.357 for x in v4]
v5 = [x*.357 for x in v5]
v6 = [x*.357 for x in v6]
v7 = [x*.357 for x in v7]
v8 = [x*.357 for x in v8]
"""
# Out:
# '\nt21 = [x+.1 for x in t21]\nt41 = [x+.1 for x in t41]\ntb = [x+.1 for x in tb]\ntc = [x-.1 for x in tc]\ntd = [x-.1 for x in td]\nte = [x-.1 for x in te]\ntf = [x-.1 for x in tf]\n\n\n#scale PG shot vertically\nv1 = [x*.357 for x in v1]\nv2 = [x*.357 for x in v2]\nv3 = [x*.357 for x in v3]\nv4 = [x*.357 for x in v4]\nv5 = [x*.357 for x in v5]\nv6 = [x*.357 for x in v6]\nv7 = [x*.357 for x in v7]\nv8 = [x*.357 for x in v8]\n'

# %%
majorLocator = MultipleLocator(.2)
majorFormatter = FormatStrFormatter('%1.2f')
minorLocator = MultipleLocator(.05)
fig, ax = plt.subplots(figsize=(25, 20))

#18-620
plt.plot(t1, v1, "b", linewidth=1.5, label="VISAR center")
plt.plot(t2, v2, 'r', linewidth=1.5, label="VISAR edge")
plt.plot(t3, v3, 'b', linewidth=1.5) #visar center
plt.plot(t4, v4, 'r', linewidth=1.5) #visar edge
plt.plot(t5, v5, 'b', linewidth=.75, label="PDV center")
plt.plot(t6, v6, 'r', linewidth=.75, label="PDV edge")
plt.plot(t7, v7, 'r', linewidth=.75) #pdv edge
plt.plot(t8, v8, 'r', linewidth=.75) #pdv edge

"""
#18-018
#plt.plot(ta,va, 'b', linewidth=1.5) #visar center
#plt.plot(tb,vb, 'r', linewidth=1.5) #visar edge
plt.plot(tc,vc, 'lime', linewidth=.75, label="18-018 PDV") #PDV center
plt.plot(td,vd, 'lime', linewidth=.75) #PDV edge
plt.plot(te,ve, 'lime', linewidth=.75) #pdv edge
plt.plot(tf,vf, 'lime', linewidth=.75) #pdv edge

#18-023
#plt.plot(t11,v11, 'b', linewidth=1.5) #VISAR center
#plt.plot(t21,v21, 'r', linewidth=1.5) #VISAR edge
#plt.plot(t31,v31, 'b', linewidth=1.5) #visar center
#plt.plot(t41,v41, 'r', linewidth=1.5) #visar edge
plt.plot(t51,v51, 'maroon', linewidth=.75, label="18-023 PDV") #PDV center
plt.plot(t61,v61, 'maroon', linewidth=.75) #PDV edge
plt.plot(t71,v71, 'maroon', linewidth=.75) #pdv edge
plt.plot(t81,v81, 'maroon', linewidth=.75) #pdv edge

"""
plt.xlabel('time (' + r'$\mu$' + 's)')
plt.ylabel('particle velocity (mm/' + r'$\mu$' + 's)')
plt.title(r'$u_p$' + " for shot 18-2s19")
plt.grid(True)
plt.legend()
#ax.yaxis.set_major_locator(majorLocator)
#ax.yaxis.set_major_formatter(majorFormatter)
#ax.yaxis.set_minor_locator(minorLocator)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
plt.yticks(np.arange(0, 4, .2))
#plt.xlim(3.2,6)
plt.ylim(-.08,4)
plt.minorticks_on()
plt.grid(b=True, which='major', linewidth=.65)
plt.grid(b=True, which='minor', linewidth=.25)


plt.show()
fig.savefig('Z:\\\\TPX\\18-2s19\\profiles.png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
#PLOTTING SHOT 18-2s19

"""
def unpack(directory, filename, *num):
    list_of_filenames = []
    for i in num:
        list_of_filenames.append(directory+filename+str(i)+".dat")
    else:
        return list_of_filenames
"""
    
directory = "Z:\\\\TPX\\18-2s19\Analysis"
filename = "\VISARvelocity"
#l = unpack(directory, filename, 1,2,3,4)

def unpack_all(directory, filename, *num):
    the_data = []
    for i in num:
        the_file_name = directory+filename+str(i)+".dat"
        the_data.append(np.loadtxt(the_file_name, delimiter=',', unpack=True))
    return the_data

data1 = unpack_all(directory, filename, 0,1,2,3)
#data is a list of lists that looks like [ [t1,v1], [t2,v2]...]
# to get t1 for example, use data[0][0]. to get v3, use data[2][1]
data2= unpack_all(directory, "\PDVvelocity", 1,2,3,4)
data = data1+data2

t1 = data[0][0]
v1 = data[0][1]
t2 = data[1][0]
v2 = data[1][1]
t3 = data[2][0]
v3 = data[2][1]
t4 = data[3][0]
v4 = data[3][1]
t5 = data[4][0]
v5 = data[4][1]
t6 = data[5][0]
v6 = data[5][1]
t7 = data[6][0]
v7 = data[6][1]
t8 = data[7][0]
v8 = data[7][1]

t1 = [x+.18 for x in t1]
t2 = [x+.175 for x in t2]
t3 = [x+.172 for x in t3]
t4 = [x+.18 for x in t4]

#adjust PDV shot vertically for downshift
v5 = [5.42101-x for x in v5]
v6 = [5.42240-x for x in v6]
v7 = [5.42235-x for x in v7]
v8 = [5.42082-x for x in v8]

#clean up after wave leaves sample
t1 = [i for i in t1 if i <= 10.16]
v1 = v1[:len(t1)]
t2 = [i for i in t2 if i <= 9.780]
v2 = v2[:len(t2)]
t3 = [i for i in t3 if i <= 10.17]
v3 = v3[:len(t3)]

t5 = [i for i in t5 if i <= 10.155]
v5 = v5[:len(t5)]
t6 = [i for i in t6 if i <= 9.8]
v6 = v6[:len(t6)]
t7 = [i for i in t7 if i <= 9.78]
v7 = v7[:len(t7)]
t8 = [i for i in t6 if i <= 9.8]
v8 = v8[:len(t8)]

#shift so that impact time is at t=0
t1 = [x-9.36 for x in t1]
t2 = [x-9.36 for x in t2]
t5 = [x-9.36 for x in t5]
t7 = [x-9.36 for x in t7]

majorLocator = MultipleLocator(.2)
majorFormatter = FormatStrFormatter('%1.2f')
minorLocator = MultipleLocator(.05)
fig, ax = plt.subplots(figsize=(25, 20))
plt.rcParams.update({'font.size': 22})

#18-2s19, choose representative PDV to show
plt.plot(t1, v1, color="#42d4f4", linewidth=3.5, label="VISAR center")
plt.plot(t2, v2, color='#e6194B', linewidth=3.5, label="VISAR edge")
#plt.plot(t3, v3, color="#42d4f4", linewidth=1.5) #visar center
#plt.plot(t4, v4, color='#e6194B', linewidth=1.5) #visar edge
plt.plot(t5, v5, color="#42d4f4", linewidth=1.5, label="PDV center")
#plt.plot(t6, v6, color='#e6194B', linewidth=.75, label="PDV edge")
plt.plot(t7, v7, color='#e6194B', linewidth=1.5, label="PDV edge") #pdv edge
#plt.plot(t8, v8, color='#e6194B', linewidth=.75) #pdv edge

plt.xlabel('time (' + r'$\mu$' + 's)', fontsize=45)
plt.ylabel('Apparent particle velocity (mm/' + r'$\mu$' + 's)', fontsize=45)
#plt.title(r'$u_p$' + " for shot 18-2s19")
#plt.grid(True)
plt.legend(fontsize=38)
#ax.yaxis.set_major_locator(majorLocator)
#ax.yaxis.set_major_formatter(majorFormatter)
#ax.yaxis.set_minor_locator(minorLocator)
#ax.xaxis.set_major_locator(majorLocator)
#ax.xaxis.set_major_formatter(majorFormatter)
#ax.xaxis.set_minor_locator(minorLocator)
plt.yticks(np.arange(0, 4.5, .5))
plt.xticks(np.arange(0, 2.5, .2))
plt.xlim(-.04,.8)
plt.ylim(-.08,4)
plt.minorticks_on()
#plt.grid(b=True, which='major', linewidth=.65)
#plt.grid(b=True, which='minor', linewidth=.25)
ax.tick_params(axis='both', which="major", length=20, width=4, direction="out", labelsize=38)
ax.tick_params(axis='both', which="minor", length=10, width=2, direction="out")

plt.show()
fig.savefig('Z:\\\\TPX\\18-2s19\\testprofiles.png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
#PLOTTING SHOT 18-023
    
directory = "Z:\\\\TPX\\18-023\Analysis"

def unpack_all(directory, filename, *num):
    the_data = []
    for i in num:
        the_file_name = directory+filename+str(i)+".dat"
        the_data.append(np.loadtxt(the_file_name, delimiter=',', unpack=True))
    return the_data

data1 = unpack_all(directory, "\VISAR\\velocity", 0,1,2,3)
data2= unpack_all(directory, "\PDV\\velocityCh", 1,2,3,4)
data = data1+data2

t1 = data[0][0]
v1 = data[0][1]
t2 = data[1][0]
v2 = data[1][1]
t3 = data[2][0]
v3 = data[2][1]
t4 = data[3][0]
v4 = data[3][1]
t5 = data[4][0]
v5 = data[4][1]
t6 = data[5][0]
v6 = data[5][1]
t7 = data[6][0]
v7 = data[6][1]
t8 = data[7][0]
v8 = data[7][1]

t1 = [x+.18 for x in t1]
t2 = [x+.10 for x in t2]
t3 = [x+.14 for x in t3]
t4 = [x+.08 for x in t4]
"""
#clean up after wave leaves sample
t1 = [i for i in t1 if i <= 10.17]
v1 = v1[:len(t1)]
t2 = [i for i in t2 if i <= 9.785]
v2 = v2[:len(t2)]
t3 = [i for i in t3 if i <= 10.17]
v3 = v3[:len(t3)]
"""
t5 = [i for i in t5 if i <= 5.62205]
v5 = v5[:len(t5)]
"""
t6 = [i for i in t6 if i <= 9.8]
v6 = v6[:len(t6)]
t7 = [i for i in t7 if i <= 9.8]
v7 = v7[:len(t7)]
t8 = [i for i in t6 if i <= 9.8]
v8 = v8[:len(t8)]
"""
#shift so that impact time is at t=0
t1 = [x-3.475 for x in t1]
t2 = [x-3.475 for x in t2]
t5 = [x-3.475 for x in t5]
t8 = [x-3.475 for x in t8]


majorLocator = MultipleLocator(.2)
majorFormatter = FormatStrFormatter('%1.2f')
minorLocator = MultipleLocator(.1)
fig, ax = plt.subplots(figsize=(25, 20))
plt.rcParams.update({'font.size': 22})

#18-023, plot only representative profiles
plt.plot(t1, v1, color="#42d4f4", linewidth=3.5, label="VISAR center")
plt.plot(t2, v2, color='#e6194B', linewidth=3.5, label="VISAR edge")
#plt.plot(t3, v3, color="#42d4f4", linewidth=1.5) #visar center
#plt.plot(t4, v4, color='#e6194B', linewidth=1.5) #visar edge
plt.plot(t5, v5, color="#42d4f4", linewidth=1.5, label="PDV center")
#plt.plot(t6, v6, color='#e6194B', linewidth=.75, label="PDV edge")
#plt.plot(t7, v7, color='#e6194B', linewidth=.75) #pdv edge
plt.plot(t8, v8, color='#e6194B', linewidth=1.5, label="PDV edge") #pdv edge

plt.xlabel('time (' + r'$\mu$' + 's)', fontsize=45)
plt.ylabel('Apparent particle velocity (mm/' + r'$\mu$' + 's)', fontsize=45)
#plt.title("Apparent particle velocity for Experiment 18-023 at 1 GPa", fontsize=32)
#plt.grid(True)
plt.legend(fontsize=38, loc=4)
#ax.yaxis.set_major_locator(majorLocator)
#ax.yaxis.set_major_formatter(majorFormatter)
#ax.yaxis.set_minor_locator(minorLocator)
#ax.xaxis.set_major_locator(majorLocator)
#ax.xaxis.set_major_formatter(majorFormatter)
#ax.xaxis.set_minor_locator(minorLocator)
plt.yticks(np.arange(0, .8, .1))
plt.xticks(np.arange(0, 2.5, .2))
#plt.xlim(3.2,6)
plt.ylim(-.02,.7)
plt.xlim(-.05,2.5)
plt.minorticks_on()
ax.tick_params(axis='both', which="major", length=20, width=4, direction="out", labelsize=38)
ax.tick_params(axis='both', which="minor", length=10, width=2, direction="out")
#plt.grid(b=True, which='major', linewidth=.65)
#plt.grid(b=True, which='minor', linewidth=.25)


plt.show()
fig.savefig('Z:\\\\TPX\\Images\\low_testprofiles.png', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
#PLOTTING ALL SHOTS, no rescaling
    

def unpack_all(directory, filename, *num):
    the_data = []
    for i in num:
        the_file_name = directory+filename+str(i)+".dat"
        the_data.append(np.loadtxt(the_file_name, delimiter=',', unpack=True))
    return the_data

data1 = unpack_all("Z:\\\\TPX\\18-2s19\Analysis", "\VISARvelocity", 0,1,2,3)
data2= unpack_all("Z:\\\\TPX\\18-2s19\Analysis", "\PDVvelocity", 1,2,3,4)
data3 = unpack_all("Z:\\\\TPX\\18-023\Analysis", "\VISAR\\velocity", 0,1,2,3)
data4= unpack_all("Z:\\\\TPX\\18-023\Analysis", "\PDV\\velocityCh", 1,2,3,4)

data = data1+data2+data3+data4

t1 = data[0][0]
v1 = data[0][1]
t2 = data[1][0]
v2 = data[1][1]
t3 = data[2][0]
v3 = data[2][1]
t4 = data[3][0]
v4 = data[3][1]
t5 = data[4][0]
v5 = data[4][1]
t6 = data[5][0]
v6 = data[5][1]
t7 = data[6][0]
v7 = data[6][1]
t8 = data[7][0]
v8 = data[7][1]
t9 = data[8][0]
v9 = data[8][1]
t10 = data[9][0]
v10 = data[9][1]
t11 = data[10][0]
v11 = data[10][1]
t12 = data[11][0]
v12 = data[11][1]
t13 = data[12][0]
v13 = data[12][1]
t14 = data[13][0]
v14 = data[13][1]
t15 = data[14][0]
v15 = data[14][1]
t16 = data[15][0]
v16 = data[15][1]

t1 = [x+.18 for x in t1]
t2 = [x+.18 for x in t2]
t3 = [x+.172 for x in t3]
t4 = [x+.18 for x in t4]


#adjust PDV shot vertically for downshift
v5 = [5.42101-x for x in v5]
v6 = [5.42240-x for x in v6]
v7 = [5.42235-x for x in v7]
v8 = [5.42082-x for x in v8]

#clean up after wave leaves sample
t1 = [i for i in t1 if i <= 10.17]
v1 = v1[:len(t1)]
t2 = [i for i in t2 if i <= 9.785]
v2 = v2[:len(t2)]
t3 = [i for i in t3 if i <= 10.17]
v3 = v3[:len(t3)]

t5 = [i for i in t5 if i <= 10.1553]
v5 = v5[:len(t5)]
t6 = [i for i in t6 if i <= 9.8]
v6 = v6[:len(t6)]
t7 = [i for i in t7 if i <= 9.8]
v7 = v7[:len(t7)]
t8 = [i for i in t6 if i <= 9.8]
v8 = v8[:len(t8)]


t9 = [x+.18+4 for x in t9]
t10 = [x+.09+4 for x in t10]
t11 = [x+.14+4 for x in t11]
t12 = [x+.08+4 for x in t12]
t13 = [x+4 for x in t13]
t14 = [x+4 for x in t14]
t15 = [x+4 for x in t15]
t16 = [x+4 for x in t16]

majorLocator = MultipleLocator(.2)
majorFormatter = FormatStrFormatter('%1.2f')
minorLocator = MultipleLocator(.05)
fig, ax = plt.subplots(figsize=(25, 20))
plt.rcParams.update({'font.size': 22})

plt.plot(t1, v1, "b", linewidth=1.5, label="VISAR center")
plt.plot(t2, v2, 'r', linewidth=1.5, label="VISAR edge")
plt.plot(t3, v3, 'b', linewidth=1.5) #visar center
plt.plot(t4, v4, 'r', linewidth=1.5) #visar edge
plt.plot(t5, v5, 'b', linewidth=.75, label="PDV center")
plt.plot(t6, v6, 'r', linewidth=.75, label="PDV edge")
plt.plot(t7, v7, 'r', linewidth=.75) #pdv edge
plt.plot(t8, v8, 'r', linewidth=.75) #pdv edge
plt.plot(t9, v9, "b", linewidth=1.5) #start 18-023
plt.plot(t10, v10, 'r', linewidth=1.5)
plt.plot(t11, v11, 'b', linewidth=1.5) 
plt.plot(t12, v12, 'r', linewidth=1.5) 
plt.plot(t13, v13, 'b', linewidth=.75)
plt.plot(t14, v14, 'r', linewidth=.75)
plt.plot(t15, v15, 'r', linewidth=.75) 
plt.plot(t16, v16, 'r', linewidth=.75) 


plt.xlabel('time (' + r'$\mu$' + 's)')
plt.ylabel('particle velocity (mm/' + r'$\mu$' + 's)')
plt.title(r'$u_p$' + " for all shots")
plt.grid(True)
plt.legend()
#ax.yaxis.set_major_locator(majorLocator)
#ax.yaxis.set_major_formatter(majorFormatter)
#ax.yaxis.set_minor_locator(minorLocator)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
plt.yticks(np.arange(0, 4, .2))
#plt.xlim(3.2,6)
plt.ylim(-.08,4)
plt.minorticks_on()
plt.grid(b=True, which='major', linewidth=.65)
plt.grid(b=True, which='minor', linewidth=.25)


plt.show()
fig.savefig('Z:\\\\TPX\\Images\\allprofiles.png', bbox_inches='tight')
#not useful, abandon this for now

# %%
# Out:
# C:\Users\lauren.barmore\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# False

# %%
#Example black and white velocity profile
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
#PLOTTING SHOT 18-023


def unpack_all(directory, filename, *num):
    the_data = []
    for i in num:
        the_file_name = directory+filename+str(i)+".dat"
        the_data.append(np.loadtxt(the_file_name, delimiter=',', unpack=True))
    return the_data

data1 = unpack_all("Z:\\\\TPX\\18-2s19\Analysis", "\VISARvelocity", 0,1,2,3)
data = data1

t4 = data[0][0]
v4 = data[0][1]

t4=[x-9 for x in t4]


majorLocator = MultipleLocator(.2)
majorFormatter = FormatStrFormatter('%1.1f')
minorLocator = MultipleLocator(.05)
fig, ax = plt.subplots(figsize=(10, 15))
plt.rcParams.update({'font.size': 35})

#18-620
plt.plot(t4, v4, 'k', linewidth=4) #visar edge


plt.xlabel('Time (' + r'$\mu$' + 's)', weight='bold')
plt.ylabel('Interface particle velocity (mm/' + r'$\mu$' + 's)', weight="bold")
plt.yticks(np.arange(0, 4, .5))
plt.xticks(np.arange(.6, 2, .1))
#plt.xlim(3.2,6)
plt.ylim(0,4)
plt.xlim(0.5,.95)
plt.text(.51,3.8,"19 GPa TPX Velocity Profile", weight="bold")
ax.tick_params(axis="both",which="both",direction='in',width=2, bottom=True,top=True, left=True, right=True,length=5)
ax.yaxis.set_minor_locator(MultipleLocator(.1))
ax.xaxis.set_minor_locator(minorLocator)


plt.show()
fig.savefig('Z:\\\\TPX\\Images\\BWprofile.png', bbox_inches='tight')
